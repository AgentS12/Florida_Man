# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93ccdb9b-2bbc-4bd8-ab63-17059e830300" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93ccdb9b-2bbc-4bd8-ab63-17059e830300">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

# Assuming you uploaded a file named 'your_file_name.csv'
df = pd.read_csv(io.StringIO(uploaded['florida_man.csv'].decode('utf-8')))

# %%
title_df = df[['title']]

# %%
title_df = title_df[title_df['title'].str.contains('Florida', case=False, na=False)]
title_df = title_df.iloc[0:500]
title_df
# Out:
#                                                  title
# 0    Florida woman backing pickup out of driveway h...
# 1    Florida man accused of assaulting girl lured a...
# 3    Florida Woman thought to have stuffed 93 year-...
# 4    Florida man strikes again, Brandon Duhaime abs...
# 5    Florida man charged with hate crimes for 'raci...
# ..                                                 ...
# 537  Florida Man Arrested After Stabbing His Sleepi...
# 538                          Florida man strike again!
# 539  Florida Man dies after crashing car into 11-fo...
# 540  Florida Man dies after crashing into 11 foot a...
# 541  Florida man killed in crash after hitting 11-f...
#
# [500 rows x 1 columns]

# %%
title_df.to_csv('title_Florida.csv', index=False)

# %%
files.download('title_Florida.csv')
